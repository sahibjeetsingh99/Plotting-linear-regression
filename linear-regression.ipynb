# %%
#creating_plots

import matplotlib.pyplot as plt

xsales = [1,2,3,4,5]
budget = [1,2,3,4,5]

plt.title('Google Ad Campaign')
plt.xlabel('budget')
plt.ylabel('sales')
plt.plot(x,y)
plt.show()

# %%
#linear_regression

import matplotlib.pyplot as plt

b = 2
c = 7
x = [1,2,3,4,5,6,7,8]
y = []
for i in x:
    result = b*i + c
    y.append(result)
    
print(y)

plt.title('Implement Linear Regression Model')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.plot(x,y)
# Out:
# [9, 11, 13, 15, 17, 19, 21, 23]
